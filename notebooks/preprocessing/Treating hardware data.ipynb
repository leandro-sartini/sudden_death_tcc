# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('T0000.CSV',sep=',',encoding = 'UTF-8',skiprows=15)

# %%
df
# Out:
#            TIME    CH1  CH1 Peak Detect
# 0      -2.00000  0.185            0.213
# 1      -1.99997  0.173            0.139
# 2      -1.99994  0.165            0.207
# 3      -1.99990  0.181            0.139
# 4      -1.99987  0.173            0.203
# ...         ...    ...              ...
# 124995  1.99984  0.191            0.151
# 124996  1.99987  0.189            0.223
# 124997  1.99990  0.193            0.151
# 124998  1.99994  0.181            0.221
# 124999  1.99997  0.191            0.155
#
# [125000 rows x 3 columns]

# %%
plt.figure(figsize = [16,8])
sns.lineplot(data=df,x=df.index,y='CH1')
# Out:
# <AxesSubplot:ylabel='CH1'>

# %%
df['smoothed'] = pd.Series(df['CH1']).rolling(window=1000).mean()

# %%
plt.figure(figsize = [16,8])
line_plot = sns.lineplot(data=df,x=df.index,y='smoothed')
fig = line_plot.get_figure()
fig.savefig('test.png')
